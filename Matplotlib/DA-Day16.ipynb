# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
filter=pd.read_csv('https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/sales_data_boolean_filtering.csv')

# %%
# Subplot():- It is used to create multiple grids

# Syntax:
#     plt.Subplot(no._of_rows,no._of_cols,position)

# %%
plt.subplot(3,3,1)
plt.plot(x,y)

plt.subplot(4,3,2)
plt.subplot(3,3,3)
plt.subplot(3,3,4)
plt.subplot(3,3,5)
plt.subplot(3,3,6)
plt.subplot(3,3,7)
plt.subplot(3,3,8)
plt.subplot(3,3,9)
plt.tight_layout()

# %%
# tight_layout-> It will create sufficient gap between subplots.

# %%
x=np.arange(1,11)
y=x**2
z=x**3

# %%
plt.subplot(4,2,1)
plt.subplot(4,2,2)
plt.subplot(4,2,3)
plt.subplot(4,2,4)
plt.subplot(4,2,5)
plt.subplot(4,2,6)
plt.subplot(4,2,7)
plt.subplot(4,2,8)

plt.tight_layout()

# %%
x=filter['Region']
y=filter['TotalSales']

# %%
ge_groups=filter.groupby('Region')['TotalSales'].sum()


# ge_north=ge_groups.get_group('North')
# ge_south=ge_groups.get_group('South')
# ge_east=ge_groups.get_group('East')
# ge_west=ge_groups.get_group('West')

# d=[ge_north,ge_south,ge_east,ge_west]

reg=pd.DataFrame(ge_groups)
reg.reset_index(inplace=True)

reg

x=reg['Region']
y=reg['TotalSales']

# %%
# plt.subplot(4,2,1)
# plt.plot(x,y)
# plt.gca().set_facecolor('#B8E6FE')
# plt.subplot(4,2,2)
# plt.subplot(4,2,3)
# plt.subplot(4,2,4)
# plt.subplot(4,2,5)
# plt.subplot(4,2,6)
# plt.subplot(4,2,7)
# plt.subplot(4,2,8)

# plt.tight_layout()

# %%
# 2) 
# syntax:

#     var=plt.figure()
#     var.add_axes([left,bottom,width,height])

# %%
fig=plt.figure(figsize=(5,5),facecolor='#3368A0')
fig.add_axes([0,0,1,1],facecolor='#218DAE')
fig.add_axes([0.1,0.1,0.8,0.8],facecolor='#2BBBD7')
fig.add_axes([0.2,0.2,0.6,0.6],facecolor='#92EEFF')
fig.add_axes([0.3,0.3,0.4,0.4],facecolor='#E3F2FD')
plt.plot(x,y)

# %%
fig=plt.figure(figsize=(15,8),facecolor='#3368A0')
fig.add_axes([0,0,1,1],facecolor='#218DAE')

plt.subplot(2,2,1)
plt.plot(x,y)
plt.tight_layout
plt.subplot(2,2,2)
plt.plot(x,y)
plt.tight_layout
plt.subplot(2,2,3)
plt.plot(x,y)
plt.tight_layout
plt.subplot(2,2,4)
plt.plot(x,y)
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad: 'float' = 1.08, h_pad: 'float | None' = None, w_pad: 'float | None' = None, rect: 'tuple[float, float, float, float] | None' = None) -> 'None'>
