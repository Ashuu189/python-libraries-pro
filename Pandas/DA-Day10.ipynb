# %%
import pandas as pd
import numpy as np

# %%
titanic=pd.read_csv('https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/titanic.csv'
'')
wine_quality=pd.read_csv('https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/winequalityN.csv')

tips=pd.read_csv('https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/tips.csv')

amazon=pd.read_csv('https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/amazon_fires.csv',encoding='ISO-8859-1')

hr=pd.read_csv('https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/hr_data.csv')

# %%
# Dropping unwanted rows.

# # Syntax:
#  var.drop(row_index)-> for single row
# var.drop([row_index1, row_index2,....])-> for multiple rows

# %%
d={'ENAME':['SMITH','ALLEN','WARD','JONES','MARTIN','BLAKE','CLARK','SCOTT','KING',np.nan,'TURNER'],
   'Eid':  [7369,7499,7521,7566,7698,7782,7788,7902,7934,7844,np.nan],
   'Salary':['8LPA','10LPA','9LPA','12LPA','15LPA','14LPA','13LPA','16LPA','20LPA','11LPA',np.nan]}

# %%
tips.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df=pd.DataFrame(d)

# %%
df
# Out:
#      ENAME     Eid Salary
# 0    SMITH  7369.0   8LPA
# 1    ALLEN  7499.0  10LPA
# 2     WARD  7521.0   9LPA
# 3    JONES  7566.0  12LPA
# 4   MARTIN  7698.0  15LPA
# 5    BLAKE  7782.0  14LPA
# 6    CLARK  7788.0  13LPA
# 7    SCOTT  7902.0  16LPA
# 8     KING  7934.0  20LPA
# 9      NaN  7844.0  11LPA
# 10  TURNER     NaN    NaN

# %%
df.drop(10)
# Out:
#     ENAME     Eid Salary
# 0   SMITH  7369.0   8LPA
# 1   ALLEN  7499.0  10LPA
# 2    WARD  7521.0   9LPA
# 3   JONES  7566.0  12LPA
# 4  MARTIN  7698.0  15LPA
# 5   BLAKE  7782.0  14LPA
# 6   CLARK  7788.0  13LPA
# 7   SCOTT  7902.0  16LPA
# 8    KING  7934.0  20LPA
# 9     NaN  7844.0  11LPA

# %%
df.drop([5,9])
# Out:
#      ENAME     Eid Salary
# 0    SMITH  7369.0   8LPA
# 1    ALLEN  7499.0  10LPA
# 2     WARD  7521.0   9LPA
# 3    JONES  7566.0  12LPA
# 4   MARTIN  7698.0  15LPA
# 6    CLARK  7788.0  13LPA
# 7    SCOTT  7902.0  16LPA
# 8     KING  7934.0  20LPA
# 10  TURNER     NaN    NaN

# %%
# axis=1---> column
# axis=0----> row

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.head()
# Out:
#       total_bill   tip smoker  day    time
# size
# 2          16.99  1.01     No  Sun  Dinner
# 3          10.34  1.66     No  Sun  Dinner
# 3          21.01  3.50     No  Sun  Dinner
# 2          23.68  3.31     No  Sun  Dinner
# 4          24.59  3.61     No  Sun  Dinner

# %%
# set_index()-> It will set the specified columns as index of dataframe.

# Syntax: 
# var.set_index('col_name',inplace=true)

# %%
# tips.set_index('size',inplace=True)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
amazon.head()
# Out:
#     ano      mes estado   numero  encontro
# 0  1998  Janeiro   Acre  0 Fires  1/1/1998
# 1  1999  Janeiro   Acre  0 Fires  1/1/1999
# 2  2000  Janeiro   Acre  0 Fires  1/1/2000
# 3  2001  Janeiro   Acre  0 Fires  1/1/2001
# 4  2002  Janeiro   Acre  0 Fires  1/1/2002

# %%
amazon.set_index('ano',inplace=True)

# %%
amazon.head()
# Out:
#           mes estado   numero  encontro
# ano
# 1998  Janeiro   Acre  0 Fires  1/1/1998
# 1999  Janeiro   Acre  0 Fires  1/1/1999
# 2000  Janeiro   Acre  0 Fires  1/1/2000
# 2001  Janeiro   Acre  0 Fires  1/1/2001
# 2002  Janeiro   Acre  0 Fires  1/1/2002

# %%
amazon.reset_index(inplace=True)

# %%
amazon.head()
# Out:
#     ano      mes estado   numero  encontro
# 0  1998  Janeiro   Acre  0 Fires  1/1/1998
# 1  1999  Janeiro   Acre  0 Fires  1/1/1999
# 2  2000  Janeiro   Acre  0 Fires  1/1/2000
# 3  2001  Janeiro   Acre  0 Fires  1/1/2001
# 4  2002  Janeiro   Acre  0 Fires  1/1/2002

# %%
appliances=pd.read_csv('https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Cleaning/uncleaned_appliances.csv')

# %%
appliances.head()
# Out:
#                               goods-title-link--jump  \
# 0  1pc Rechargeable Deep Tissue Muscle Handheld M...
# 1                      1pc Portable Hanging Neck Fan
# 2  1pc Pink Colored Curved Eyelash Curler False E...
# 3  1 Mini Portable Handheld Fan With 2 Aa Batteri...
# 4  Wit Water Flosser,Portable Oral Irrigator With...
#
#                          goods-title-link--jump href       rank-title  \
# 0  https://us.shein.com/1pc-Rechargeable-Deep-Tis...  #1 Best Sellers
# 1  https://us.shein.com/1pc-Portable-Hanging-Neck...  #4 Best Sellers
# 2  https://us.shein.com/1pc-Pink-Colored-Curved-E...              NaN
# 3  https://us.shein.com/1-Mini-Portable-Handheld-...              NaN
# 4  https://us.shein.com/Wit-Water-Flosser-Portabl...  #6 Best Sellers
#
#                         rank-sub   price discount  selling_proposition  \
# 0                  in Give Gifts   $2.03     -22%                  NaN
# 1  in Top rated in Portable Fans   $6.48     -20%                  NaN
# ...

# %%
appliances.duplicated().sum()
# Out:
# np.int64(209)

# %%
appliances.drop_duplicates(inplace=True)

# %%
appliances.duplicated().sum()
# Out:
# np.int64(0)

# %%
appliances.shape
# Out:
# (3777, 8)

# %%
appliances.notnull().sum()
# Out:
# goods-title-link--jump           40
# goods-title-link--jump href      40
# rank-title                      559
# rank-sub                        559
# price                          3777
# discount                       2259
# selling_proposition            1352
# goods-title-link               3737
# dtype: int64

# %%
appliances['goods-title-link'].unique()
# Out:
# <StringArray>
# [                                                                                                                                                                                                                                                   nan,
#                                                                                             '4pcs Makeup Sponge Beauty Egg Set - Makeup Sponge For Foundation Blending With Egg Holder, Perfectly Used For Cream, Powder, Blush, Concealer, And Liquid',
#                                                                                                                  '1pc Salon Tools Black Pink Universal Silicone Hair Dryer Diffuser Hood Adjustable Temperature Dispersion Resistant Drying Hair Dryer',
# ...

# %%
appliances.head()
# Out:
#                               goods-title-link--jump  \
# 0  1pc Rechargeable Deep Tissue Muscle Handheld M...
# 1                      1pc Portable Hanging Neck Fan
# 2  1pc Pink Colored Curved Eyelash Curler False E...
# 3  1 Mini Portable Handheld Fan With 2 Aa Batteri...
# 4  Wit Water Flosser,Portable Oral Irrigator With...
#
#                          goods-title-link--jump href       rank-title  \
# 0  https://us.shein.com/1pc-Rechargeable-Deep-Tis...  #1 Best Sellers
# 1  https://us.shein.com/1pc-Portable-Hanging-Neck...  #4 Best Sellers
# 2  https://us.shein.com/1pc-Pink-Colored-Curved-E...              NaN
# 3  https://us.shein.com/1-Mini-Portable-Handheld-...              NaN
# 4  https://us.shein.com/Wit-Water-Flosser-Portabl...  #6 Best Sellers
#
#                         rank-sub   price discount  selling_proposition  \
# 0                  in Give Gifts   $2.03     -22%                  NaN
# 1  in Top rated in Portable Fans   $6.48     -20%                  NaN
# ...

# %%
appliances.drop(['goods-title-link--jump','goods-title-link--jump href','goods-title-link'],inplace=True, axis= 1)

# %%
appliances.head()
# Out:
#          rank-title                       rank-sub   price discount  \
# 0   #1 Best Sellers                  in Give Gifts   $2.03     -22%
# 3               NaN                            NaN   $0.88     -72%
# 4   #6 Best Sellers             in Oral Irrigators  $12.06     -40%
# 5  #10 Best Sellers    in Refrigerators & Freezers   $2.70      NaN
# 6   #8 Best Sellers  in Other Household Appliances   $3.50      NaN
#
#    selling_proposition
# 0                  NaN
# 3  5.6k+ sold recently
# 4                  NaN
# 5                  NaN
# 6                  NaN

# %%
appliances['rank-title'].unique()
# Out:
# <StringArray>
# [ '#1 Best Sellers',                nan,  '#6 Best Sellers',
#  '#10 Best Sellers',  '#8 Best Sellers',  '#9 Best Sellers',
#   '#5 Best Sellers',  '#2 Best Sellers',  '#7 Best Sellers',
#   '#3 Best Sellers',  '#4 Best Sellers']
# Length: 11, dtype: str

# %%
appliances['rank-title']=appliances['rank-title'].str.strip('# Best Sellers')

# %%
appliances.head()
# Out:
#   rank-title                       rank-sub   price discount  \
# 0          1                  in Give Gifts   $2.03     -22%
# 3        NaN                            NaN   $0.88     -72%
# 4          6             in Oral Irrigators  $12.06     -40%
# 5         10    in Refrigerators & Freezers   $2.70      NaN
# 6          8  in Other Household Appliances   $3.50      NaN
#
#    selling_proposition
# 0                  NaN
# 3  5.6k+ sold recently
# 4                  NaN
# 5                  NaN
# 6                  NaN

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 appliances.astype(Int64)
#
# NameError: name 'Int64' is not defined

# %%
appliances['rank-title']=appliances['rank-title'].astype('Int64')

# %%
appliances.head()
# Out:
#    rank-title                       rank-sub   price discount  \
# 0           1                  in Give Gifts   $2.03     -22%
# 3        <NA>                            NaN   $0.88     -72%
# 4           6             in Oral Irrigators  $12.06     -40%
# 5          10    in Refrigerators & Freezers   $2.70      NaN
# 6           8  in Other Household Appliances   $3.50      NaN
#
#    selling_proposition
# 0                  NaN
# 3  5.6k+ sold recently
# 4                  NaN
# 5                  NaN
# 6                  NaN

# %%
appliances['rank-title'].unique()
# Out:
# <IntegerArray>
# [1, <NA>, 6, 10, 8, 9, 5, 2, 7, 3, 4]
# Length: 11, dtype: Int64

# %%
avg= round(appliances['rank-title'].mean())

avg
# Out:
# 5

# %%
ua['rank-title']
