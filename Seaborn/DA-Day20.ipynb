# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tips=pd.read_csv('https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/tips.csv')
wine_quality=pd.read_csv('https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/winequalityN.csv')
titanic=pd.read_csv('https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/titanic.csv' \
'')    
amazon=pd.read_csv('https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/amazon_fires.csv',encoding='ISO-8859-1')
hr=pd.read_csv('https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/hr_data.csv')

# %%
wine_quality.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
wine_quality['quality'].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9])

# %%
q3=wine_quality['quality'].quantile(0.75)
q1=wine_quality['quality'].quantile(0.25)

# %%
iqr=q3-q1

# %%
iqr
# Out:
# np.float64(1.0)

# %%
lower_bound=q1-0.5*iqr
upper_bound=q3+0.5*iqr


lower_bound,upper_bound
# Out:
# (np.float64(4.5), np.float64(6.5))

# %%
outlier=wine_quality[(wine_quality['quality']< lower_bound) | (wine_quality['quality']> upper_bound)].count()

# %%
outlier
# Out:
# type                    1523
# fixed acidity           1522
# volatile acidity        1521
# citric acid             1523
# residual sugar          1522
# chlorides               1522
# free sulfur dioxide     1523
# total sulfur dioxide    1523
# density                 1523
# pH                      1521
# sulphates               1522
# alcohol                 1523
# quality                 1523
# dtype: int64

# %%
out=[]
for i in wine_quality['quality']:
    if i>upper_bound:
        out.append(upper_bound)
    elif i<lower_bound:
        out.append(lower_bound)
    else:
        out.append(i)

wine_quality['quality']=out

# %%
wine_quality['quality']
# Out:
# 0       6.0
# 1       6.0
# 2       6.0
# 3       6.0
# 4       6.0
#        ...
# 6492    5.0
# 6493    6.0
# 6494    6.0
# 6495    5.0
# 6496    6.0
# Name: quality, Length: 6497, dtype: float64

# %%
# Scatter-plot-> 

# It is used to understand the relationship between two variable.

# syntax: 
# sns.scatterplot(x='col_name',y='col_name',data=var)

# %%
sns.scatterplot(x='total_bill',y='tip',hue='sex',data=tips,palette='magma' )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#violinplot():-
# It is used to identify exact where the number of datapoints are present.

# Syntax: sns.violinplot(x='col_1', y='col_2',data=var)

# %%
sns.violinplot(x='type', y='quality',data=wine_quality, palette='magma')
# Out:
# C:\Users\ashut\AppData\Local\Temp\ipykernel_9704\1994823541.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='type', y='quality',data=wine_quality, palette='magma')
# <Axes: xlabel='type', ylabel='quality'>

# %%
sns.violinplot(x='sex', y='total_bill',data=tips,hue='size',  palette='magma')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
tips.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic=pd.read_csv('https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/titanic.csv' \
'')

# %%
sns.violinplot(x='sex', y='age',data=titanic, hue='survived' , palette='magma')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
titanic.head()
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked  survived
# 0      0      0   24160  211.3375       B5        S         1
# 1      1      2  113781  151.5500  C22 C26        S         1
# 2      1      2  113781  151.5500  C22 C26        S         0
# 3      1      2  113781  151.5500  C22 C26        S         0
# 4      1      2  113781  151.5500  C22 C26        S         0

# %%
# Matrix plot:- 

# It is used to compare one column with another column.

# It is mainly used in case of machine learning

# why we use?

# To observe relation between multiple columns.

# Syntax= 

# var_1=['col_1','col_2'...]
# sns.heatmap(data=var[var_1].corr(),annote=True,cmap='coolwarm')

# %%
var_1=['pH','quality','density']
sns.heatmap(data=wine_quality[var_1].corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
hr.head()
# Out:
#    employee_id  number_project  average_montly_hours  time_spend_company  \
# 0         1003               2                   157                   3
# 1         1005               5                   262                   6
# 2         1486               7                   272                   4
# 3         1038               5                   223                   5
# 4         1057               2                   159                   3
#
#    Work_accident  left  promotion_last_5years department  salary
# 0              0     1                      0      sales     low
# 1              0     1                      0      sales  medium
# 2              0     1                      0      sales  medium
# 3              0     1                      0      sales     low
# 4              0     1                      0      sales     low

# %%
c=['employee_id','number_project','average_montly_hours','time_spend_company','Work_accident','left']

# %%
sns.heatmap(data=hr[c].corr(),annot=True,cmap='magma')
# Out:
# <Axes: >

# %%
#  Regression-> 
#  Continuous prediction based on past data.
#  It is used to find the relationship between multiple columns.

# Syntax-> sns.lmplot(x='col_name1',y='col_name2',data=var)
# It will also accepts numeric data.

# %%
sns.lmplot(x='tip',y='total_bill',data=tips,scatter=False)
