# %%
import pandas as pd

# %%
cafe= pd.read_csv('https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Cleaning/dirty_cafe_sales.csv')

# %%
cafe.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
cafe
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
cafe.duplicated().sum()
# Out:
# np.int64(0)

# %%
cafe['Transaction ID'].unique()
# Out:
# <StringArray>
# ['TXN_1961373', 'TXN_4977031', 'TXN_4271903', 'TXN_7034554', 'TXN_3160411',
#  'TXN_2602893', 'TXN_4433211', 'TXN_6699534', 'TXN_4717867', 'TXN_2064365',
#  ...
#  'TXN_1538510', 'TXN_3897619', 'TXN_2739140', 'TXN_4766549', 'TXN_7851634',
#  'TXN_7672686', 'TXN_9659401', 'TXN_5255387', 'TXN_7695629', 'TXN_6170729']
# Length: 10000, dtype: str

# %%
cafe['Item'].unique()
# Out:
# <StringArray>
# [  'Coffee',     'Cake',   'Cookie',    'Salad', 'Smoothie',  'UNKNOWN',
#  'Sandwich',        nan,    'ERROR',    'Juice',      'Tea']
# Length: 11, dtype: str

# %%
cafe['Payment Method'].unique()
# Out:
# <StringArray>
# ['Credit Card', 'Cash', 'UNKNOWN', 'Digital Wallet', 'ERROR', nan]
# Length: 6, dtype: str

# %%
cafe['Transaction ID']=cafe['Transaction ID'].str.strip('TXN')

# %%
cafe['Transaction ID'].unique()
# Out:
# <StringArray>
# ['_1961373', '_4977031', '_4271903', '_7034554', '_3160411', '_2602893',
#  '_4433211', '_6699534', '_4717867', '_2064365',
#  ...
#  '_1538510', '_3897619', '_2739140', '_4766549', '_7851634', '_7672686',
#  '_9659401', '_5255387', '_7695629', '_6170729']
# Length: 10000, dtype: str

# %%
cafe['Transaction ID']=cafe['Transaction ID'].str.replace('_','CF')

# %%
cafe.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0      CF1961373  Coffee        2            2.0         4.0     Credit Card
# 1      CF4977031    Cake        4            3.0        12.0            Cash
# 2      CF4271903  Cookie        4            1.0       ERROR     Credit Card
# 3      CF7034554   Salad        2            5.0        10.0         UNKNOWN
# 4      CF3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
cafe['Transaction ID'].isnull().sum()
# Out:
# np.int64(0)

# %%
cafe.isnull().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
cafe.dropna(inplace=True)

# %%
cafe.isnull().sum()
# Out:
# Transaction ID      0
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# dtype: int64

# %%
cafe.head(50)
# Out:
#     Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0        CF1961373    Coffee        2            2.0         4.0
# 1        CF4977031      Cake        4            3.0        12.0
# 2        CF4271903    Cookie        4            1.0       ERROR
# 3        CF7034554     Salad        2            5.0        10.0
# 4        CF3160411    Coffee        2            2.0         4.0
# 6        CF4433211   UNKNOWN        3            3.0         9.0
# 7        CF6699534  Sandwich        4            4.0        16.0
# 10       CF2548360     Salad        5            5.0        25.0
# 11       CF3051279  Sandwich        2            4.0         8.0
# 12       CF7619095  Sandwich        2            4.0         8.0
# 15       CF2847255     Salad        3            5.0        15.0
# 17       CF6769710     Juice        2            3.0         6.0
# 18       CF8876618      Cake        5            3.0        15.0
# ...

# %%
new=[0,2,1,3,4,5,6,7]

# %%
cafe=cafe[cafe.columns[new]]

# %%
cafe.head()
# Out:
#   Transaction ID Quantity    Item Price Per Unit Total Spent  Payment Method  \
# 0      CF1961373        2  Coffee            2.0         4.0     Credit Card
# 1      CF4977031        4    Cake            3.0        12.0            Cash
# 2      CF4271903        4  Cookie            1.0       ERROR     Credit Card
# 3      CF7034554        2   Salad            5.0        10.0         UNKNOWN
# 4      CF3160411        2  Coffee            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
cafe.set_index('Transaction ID',inplace=True)

# %%
cafe.head()
# Out:
#                Quantity    Item Price Per Unit Total Spent  Payment Method  \
# Transaction ID
# CF1961373             2  Coffee            2.0         4.0     Credit Card
# CF4977031             4    Cake            3.0        12.0            Cash
# CF4271903             4  Cookie            1.0       ERROR     Credit Card
# CF7034554             2   Salad            5.0        10.0         UNKNOWN
# CF3160411             2  Coffee            2.0         4.0  Digital Wallet
#
#                 Location Transaction Date
# Transaction ID
# CF1961373       Takeaway       2023-09-08
# CF4977031       In-store       2023-05-16
# CF4271903       In-store       2023-07-19
# CF7034554        UNKNOWN       2023-04-27
# CF3160411       In-store       2023-06-11

# %%
cafe.drop('Location',axis=1,inplace=True)

# %%
cafe.head()
# Out:
#                Quantity    Item Price Per Unit Total Spent  Payment Method  \
# Transaction ID
# CF1961373             2  Coffee            2.0         4.0     Credit Card
# CF4977031             4    Cake            3.0        12.0            Cash
# CF4271903             4  Cookie            1.0       ERROR     Credit Card
# CF7034554             2   Salad            5.0        10.0         UNKNOWN
# CF3160411             2  Coffee            2.0         4.0  Digital Wallet
#
#                Transaction Date
# Transaction ID
# CF1961373            2023-09-08
# CF4977031            2023-05-16
# CF4271903            2023-07-19
# CF7034554            2023-04-27
# CF3160411            2023-06-11
