# %%
import pandas as pd

# %%
d={'Ename':['a','s','h','u','t','o','s','h'],
   'age':[1,2,3,4,5,6,7,8]}

# %%
x=pd.DataFrame(d)

# %%
x
# Out:
#   Ename  age
# 0     a    1
# 1     s    2
# 2     h    3
# 3     u    4
# 4     t    5
# 5     o    6
# 6     s    7
# 7     h    8
